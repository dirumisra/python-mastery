# %%
import math_utils

print(math_utils.add(5, 3))         # 8
print(math_utils.area_circle(4))    # 50.26
# Out:
# 8
# 50.26544

# %% [markdown]
# Importing Specific Items

# %%
# Importing specific functions and constants from the math_utils module
# 'add' is assumed to be a function that adds two numbers
# 'PI' is assumed to be a constant representing the mathematical value of π (approximately 3.14159)
from math_utils import add, PI

# Calling the 'add' function with arguments 2 and 3
# This will compute the sum of 2 and 3, which should be 5
print(add(2, 3))  # Output: 5

# Printing the value of the constant PI
# This will output the value of π as defined in the math_utils module
print(PI)  # Output: e.g., 3.141592653589793
# Out:
# 5
# 3.14159

# %% [markdown]
# Renaming Modules or Functions
# - Use aliases for readability.

# %%
import math_utils as mu
print(mu.area_circle(5))
# Out:
# 78.53975

# %%
import math

math.sqrt(16)
# Out:
# 4.0

# %%
from math import  sqrt,pi

print(math.sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy as np

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import  *

# %%
sqrt(12)
# Out:
# 3.4641016151377544
